# %% [markdown]
# <a href="https://colab.research.google.com/github/eli-mancini/snowpoles/blob/main/SRRWPreprocessCode.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
#Data download and preprocess code
# !pip install -q condacolab
import condacolab
condacolab.install()
# !pip install -q argparse
import argparse
# !pip install -q datetime
import datetime
import torch
import cv2
import numpy as np
import glob
import pandas as pd
from tqdm import tqdm
import matplotlib.pyplot as plt
from scipy.spatial import distance
import os
import IPython

#Model environment and Model demo from Breen README
# !git clone https://github.com/eli-mancini/snowpoles
# %cd snowpoles
# !conda env update -f environment.yml
# !conda init
# !conda activate snowkeypoint
# !python src/demo.py

#photo labeling code
#HI LIZ as of 11/10/24, I do not have all of this entirely figured out!
#I currently am not authorized to access my lab's photo drive and am working with the Research Computing group to get this solved
python preprocess/rename_photos.py
python src/labeling.py --datapath 'SleepersRiver' --pole_length '121.92' --subset_to_label '10'
# Out:
# ✨🍰✨ Everything looks OK!
# Cloning into 'snowpoles'...
# remote: Enumerating objects: 398, done.
# remote: Counting objects: 100% (193/193), done.
# remote: Compressing objects: 100% (178/178), done.
# remote: Total 398 (delta 110), reused 13 (delta 13), pack-reused 205 (from 1)
# Receiving objects: 100% (398/398), 61.12 MiB | 36.07 MiB/s, done.
# Resolving deltas: 100% (216/216), done.
# /content/snowpoles/snowpoles/snowpoles
# Channels:
#  - conda-forge
# Platform: linux-64
# done
# done
#
#
# ==> WARNING: A newer version of conda exists. <==
#     current version: 23.11.0
#     latest version: 24.9.2
#
# Please update conda by running
#
#     $ conda update -n base -c conda-forge conda
#
#
#
# ...
# mkl-2023.2.0         | 156.8 MB  | :   0% 0/1 [00:00<?, ?it/s]
# qt-main-5.15.15      | 50.1 MB   | :   0% 0/1 [00:00<?, ?it/s]
#
# libtorch-2.4.0       | 49.5 MB   | :   0% 0/1 [00:00<?, ?it/s]
#
#
# qt6-main-6.7.3       | 45.1 MB   | :   0% 0/1 [00:00<?, ?it/s]
#
#
#
# ...
